# %%
#AGH
#Script for downloading evapotranspiration files

import requests
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup
from urllib import request
import urllib3
import re

# %%
#Setting the month range to download
month= []
for i in range(9,10):
    month.append("{:02d}".format(i))

print(month)

# %%
#Setting the request parameters and downloading the nc evapotranspiration files

url = 'https://datalsasaf.lsasvcs.ipma.pt'
username = 'yyara'
password = '*******'
response = requests.post(url, auth=HTTPBasicAuth(username, password))
response.status_code
destfile= "C:/Users/usuario/OneDrive/Desktop/AGH/RunOff/DataCatalog/backup"
http = urllib3.PoolManager()

for i in range(0,len(month)):
    print(month[i])
    response = http.request('GET', url + '/PRODUCTS/MSG/MDMET/NETCDF/2022/' + month[i])
    soup = BeautifulSoup(response.data)
    daysMonth= []
    for link in soup.findAll('a'):
        if "/" + month[i] + "/" in link.get('href'):
            daysMonth.append(url + link.get('href')) 
            response2 = request.urlretrieve(url + link.get('href'), destfile + "/MDMET_" + month[i] + "_" + link.get('href')[-3:-1] + ".nc")
            print(url + link.get('href'))
            print(destfile + "MDMET_" + month[i] + "_" + link.get('href')[-3:-1])
            urllib.request.urlretrieve(u + link.get('href'), destfile + "/" + (u + link.get('href')).split("/")[-1])
    #print(daysMonth)

# %%
#Reprojecting nc files to WGS84
from osgeo import gdal, osr
import rioxarray

# %%
destfile= "C:/Users/usuario/OneDrive/Desktop/AGH/RunOff/DataCatalog/backup"
nc1= destfile + '/NETCDF4_LSASAF_MSG_MEMD_MSG-Disk_202209010000.nc'
evapo = rioxarray.open_rasterio(nc1)

# %%
evapo.crs
# Out:
# <xarray.DataArray 'crs' ()>
# array(0)
# Coordinates:
#     crs      int32 0
# Attributes:
#     crs_wkt:                      GEOGCS["unknown",DATUM["unnamed",SPHEROID["...
#     semi_major_axis:              6378137.0
#     semi_minor_axis:              6356752.314245179
#     inverse_flattening:           298.257223563
#     reference_ellipsoid_name:     Spheroid
#     longitude_of_prime_meridian:  0.0
#     prime_meridian_name:          Greenwich
#     geographic_crs_name:          unknown
#     grid_mapping_name:            latitude_longitude
#     spatial_ref:                  GEOGCS["unknown",DATUM["unnamed",SPHEROID["...
#     GeoTransform:                 -80.025 0.05 0.0 80.025 0.0 -0.05

# %%
rds = rioxarray.open_rasterio(r"C:\Users\usuario\OneDrive\Desktop\AGH\RunOff\DataCatalog\backup\RasterReference.tif")
